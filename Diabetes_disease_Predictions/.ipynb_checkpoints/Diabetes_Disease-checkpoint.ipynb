# %% [markdown]
# # Diabetes Disease Prediction

# %% [markdown]
# *Importing Libraries*

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# *Loading DataSet*

# %%
df_train = pd.read_csv('Training.csv')
df_test = pd.read_csv('Testing.csv')
df_train.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df_train.shape
# Out:
# (2460, 9)

# %%
df_train.nunique()
# Out:
# Pregnancies                  17
# Glucose                     123
# BloodPressure                43
# SkinThickness                50
# Insulin                     144
# BMI                         216
# DiabetesPedigreeFunction    365
# Age                          49
# Outcome                       2
# dtype: int64

# %%
df_train.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# # EDA

# %%
plt.figure(figsize=(20,10))
sns.boxplot(df_train)
# Out:
# <Axes: >

# %% [markdown]
# ## Removing Outliers

# %%
def replace_outliers(df):
    for col in df.columns.to_list():
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5*IQR
        upper = Q3 + 1.5*IQR
        df[col] = np.where(df[col] > upper, upper, df[col])
        df[col] = np.where(df[col] < lower, lower, df[col])
        
replace_outliers(df_train)
replace_outliers(df_test)
plt.figure(figsize=(20,10))
sns.boxplot(df_train)
# Out:
# <Axes: >

# %% [markdown]
# ## Analysing The Correlation Between Features

# %%
sns.pairplot(df_train)

# %%
plt.figure(figsize=(7,7))
sns.heatmap(df_train.corr(),cmap='coolwarm',annot=True)
# Out:
# <Axes: >

# %%
sns.lmplot(df_train,x='Outcome',y='Glucose')

# %%
sns.lmplot(df_train,x='Outcome',y='BMI')

# %% [markdown]
# ## Insights
#
# - We Can See the Consumption of Insulin(Used To Control Gluscose) is Higher in Diabetes Patients and Skin thickness
# - Higher Concentration Of gluscose Can Lead To Diabetes
# - Higher Body-Mass Index Ratio Also Acts As a Catalyst for Positive In Diabetes

# %% [markdown]
# # Model Training

# %%
from sklearn.linear_model import LogisticRegression
Lr = LogisticRegression()

# %%
y_train = df_train['Outcome']
X_train = df_train.drop(['Outcome'],axis=1)
y_test = df_test['Outcome']
X_test = df_test.drop(['Outcome'],axis=1)
Lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
pred_lr = Lr.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.89      0.87       215
#          1.0       0.72      0.62      0.67        93
#
#     accuracy                           0.81       308
#    macro avg       0.78      0.76      0.77       308
# weighted avg       0.81      0.81      0.81       308
